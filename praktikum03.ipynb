# %% [markdown]
# <a href="https://colab.research.google.com/github/bimabugkus/Praktikum-Visdat-kel25-Rochmad-Bima-Setyawan/blob/main/praktikum03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #praktikum 03: Matplotlib - line plot**
#
# kelompok25:**
#   Rochmad Bima Setyawan (0110122152)
#   Silvia Pitriani (0110222136)
#   Pandu Linggar Kumara (0110221277)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Dataset

# %%
#Buat data sampel
months = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']
product_A_sales = [10,20,15,25,30,45,40,50,60,55,65,70]
product_B_sales = [5,10,8,15,18,20,22,30,25,36,40,45]

# %%
#line plot 1 garis, style grafik default
plt.plot(months, product_A_sales, label='Product A')
plt.title('Penjualan Produk A per bulan')
plt.xlabel('Bulan')
plt.ylabel('Penjualan')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Multiple Line Plot&Customizations

# %%
plt.plot(months, product_A_sales, label='Product A', linestyle="--", marker="o", color="blue")
plt.plot(months, product_B_sales, label='Product B', linestyle="-", marker="x", color="red")

plt.title('Penjualan Produk per bulan')
plt.xlabel('Bulan')
plt.ylabel('Penjualan')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Jenis Garis untuk Menunjukan Tren

# %%
#Data sampel tambahan
product_C_sales = [18,22,15,25,33,55,45,60,70,50,50,70]
product_D_sales = [7,12,10,17,20,22,24,32,27,38,42,47]

#plot prooduct A
plt.plot(months, product_A_sales, label='Product A', linestyle="--", color="blue")
plt.plot(months, product_B_sales, label='Product B', linestyle="-", color="red")
plt.plot(months, product_C_sales, label='Product C', linestyle=":", color="green")
plt.plot(months, product_D_sales, label='Product D', linestyle="-.", color="purple")

plt.title('Penjualan Produk per bulan')
plt.xlabel('Bulan')
plt.ylabel('Penjualan')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
#   Subplot pada Line Chart

# %%
#subplot, 2 baris 1 kolom, panjang 10 inch, tinggi 8 inch
fig, axs = plt.subplots(2, 1, figsize=(10,8))

#plot pertama untuk produk C
axs[0].plot(months, product_C_sales, label='Product C', color='green', marker='d')
axs[0].set_title('Penjualan Produk C per bulan')
axs[0].set_xlabel('Bulan')
axs[0].set_ylabel('Penjualan')
axs[0].legend()
axs[0].grid(True)

#plot kedua untuk produk D
axs[1].plot(months, product_D_sales, label='Product D', color='purple', marker='s')
axs[1].set_title('Penjualan Produk D per bulan')
axs[1].set_xlabel('Bulan')
axs[1].set_ylabel('Penjualan')
axs[1].legend()
axs[1].grid(True)

plt.tight_layout()
plt.show()
